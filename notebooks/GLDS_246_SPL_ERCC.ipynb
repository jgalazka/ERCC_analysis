# %% [markdown]
# <a href="https://colab.research.google.com/github/jgalazka/ERCC_analysis/blob/main/notebooks/GLDS_246_SPL_ERCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GeneLab ERCC spike-in analysis notebook
#
# This notebook contains an analysis of RNA-seq counts data generated from ERCC spike-ins.
#
# Here GLDS-246 is analyzed.

# %% [markdown]
# ## Setting up the notebook

# %%
# import python packages
import pandas as pd
pd.set_option('mode.chained_assignment', None) # suppress chained indexing warnings
import numpy as np
from urllib.request import urlopen, quote, urlretrieve
from json import loads
from re import search
import zipfile
import seaborn as sns
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %% [markdown]
# ## GeneLab metadata from URL
#
# Before you begin, visit https://genelab-data.ndc.nasa.gov and browse a GLDS accession # of interest for your analysis.<br>
# ISA.zip metadata from URL contains sample ID and transcription profile for RNA-Seq text files used in this analysis. <br>
# Function below allows the user to retrieve ISA.zip file without relying on exact version of the data as the versions change.

# %%
# Function to pull metadata zip from GeneLab
# Credit to Kirill Grigorev
GENELAB_ROOT = "https://genelab-data.ndc.nasa.gov"
GLDS_URL_PREFIX = GENELAB_ROOT + "/genelab/data/study/data/"
FILELISTINGS_URL_PREFIX = GENELAB_ROOT + "/genelab/data/study/filelistings/"
ISA_ZIP_REGEX = r'.*_metadata_.*[_-]ISA\.zip$'

def read_json(url):
    with urlopen(url) as response:
        return loads(response.read().decode())

def get_isa(accession):
    glds_json = read_json(GLDS_URL_PREFIX + accession)
    try:
        _id = glds_json[0]["_id"]
    except (AssertionError, TypeError, KeyError, IndexError):
        raise ValueError("Malformed JSON?")
    isa_entries = [
        entry for entry in read_json(FILELISTINGS_URL_PREFIX + _id)
        if search(ISA_ZIP_REGEX, entry["file_name"])
    ]
    if len(isa_entries) == 0:
        raise ValueError("Unexpected: no ISAs found")
    elif len(isa_entries) > 1:
        raise ValueError("Unexpected: multiple files match the ISA regex")
    else:
        entry = isa_entries[0]
        version = entry["version"]
        url = GENELAB_ROOT + entry["remote_url"] + "?version={}".format(version)
        alt_url = (
            GENELAB_ROOT + "/genelab/static/media/dataset/" +
            quote(entry["file_name"]) + "?version={}".format(version)
        )
        return entry["file_name"], version, url, alt_url

# %% [markdown]
# The same GLDS accession # contains an unnormalized counts text file used in this analysis. <br>
# Function below allows the user to retrieve Unnormalized_Counts.csv without relying on exact version of the data as the versions change.

# %%
# Function to pull unnormalized counts from GeneLab
# Credit to Kirill Grigorev

RAW_COUNTS_REGEX = r'.*_rna_seq_Unnormalized_Counts.csv'

def get_rawcounts(accession):
    glds_json = read_json(GLDS_URL_PREFIX + accession)
    try:
        _id = glds_json[0]["_id"]
    except (AssertionError, TypeError, KeyError, IndexError):
        raise ValueError("Malformed JSON?")
    raw_counts_entries = [
        entry for entry in read_json(FILELISTINGS_URL_PREFIX + _id)
        if search(RAW_COUNTS_REGEX, entry["file_name"])
    ]
    if len(raw_counts_entries) == 0:
        raise ValueError("Unexpected: no Raw Counts found")
    elif len(raw_counts_entries) > 1:
        raise ValueError("Unexpected: multiple files match the Raw Counts regex")
    else:
        entry = raw_counts_entries[0]
        version = entry["version"]
        url = GENELAB_ROOT + entry["remote_url"] + "?version={}".format(version)
        alt_url = (
            GENELAB_ROOT + "/genelab/static/media/dataset/" +
            quote(entry["file_name"]) + "?version={}".format(version)
        )
        return entry["file_name"], version, url, alt_url

# %% [markdown]
# ## Get and parse data and metadata
# Get and unzip ISA.zip, counts, and ERCC data.

# %%
accession = 'GLDS-246' # Change this as necessary
isaurl = get_isa(accession)[3]
filehandle, _ = urlretrieve(isaurl)
zip_file_object = zipfile.ZipFile(filehandle, 'r')
zip_file_object.namelist() # Print contents of zip file. Pick relevant one from list
# Out:
# ['.DS_Store',
#  's_RR6_SPL.txt',
#  'a_rr6_spl_transcription_profiling_RNA_Sequencing_(RNA-Seq).txt',
#  'i_Investigation.txt']

# %% [markdown]
# There are datasets that have multiple assays (including microarray), so holding ISA file based on location in above cell block will not always work. <br>Txt files outputted above are indexed as 0, 1, 2, etc. Fill in below at the end bracket of the number .txt file that corresponds to a for assay_file and s for sample_file.

# %%
sample_file = zip_file_object.namelist()[1]
file = zip_file_object.open(sample_file)
sample_table = pd.read_csv(zip_file_object.open(sample_file), sep='\t')

assay_file = zip_file_object.namelist()[2]
file = zip_file_object.open(assay_file)
assay_table = pd.read_csv(zip_file_object.open(assay_file), sep='\t')

# %%
sample_table.head(n=3)
# Out:
#        Source Name  ...                   Term Accession Number.13
# 0  LAR Baseline 3   ...  http://purl.obolibrary.org/obo/UO_0000027
# 1   LAR Baseline 4  ...  http://purl.obolibrary.org/obo/UO_0000027
# 2   LAR Baseline 5  ...  http://purl.obolibrary.org/obo/UO_0000027
#
# [3 rows x 61 columns]

# %%
assay_table.head(n=3)
# Out:
#                        Sample Name  ... Term Accession Number.19
# 0  Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  ...                      NaN
# 1  Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  ...                      NaN
# 2  Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  ...                      NaN
#
# [3 rows x 81 columns]

# %%
# Get raw counts table
raw_counts_file = get_rawcounts(accession)[3]
raw_counts_table = pd.read_csv(raw_counts_file, index_col=0)
raw_counts_table.index.rename('Gene_ID', inplace=True)
raw_counts_table.head(n=3)
# Out:
#                     Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  ...  Mmus_C57-6T_SPL_FLT_ISS-T_Rep7_F10
# Gene_ID                                              ...
# ENSMUSG00000000001                             18.0  ...                                 7.0
# ENSMUSG00000000003                              0.0  ...                                 0.0
# ENSMUSG00000000028                              6.0  ...                                 1.0
#
# [3 rows x 44 columns]

# %%
raw_counts_transcripts = raw_counts_table[raw_counts_table.index.str.contains('^ENSMUSG')]
raw_counts_transcripts = raw_counts_transcripts.sort_values(by=list(raw_counts_transcripts), ascending=False)
raw_counts_transcripts
# Out:
#                     Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  ...  Mmus_C57-6T_SPL_FLT_ISS-T_Rep7_F10
# Gene_ID                                              ...
# ENSMUSG00000075015                        495821.83  ...                               26.95
# ENSMUSG00000097312                        370289.00  ...                               29.00
# ENSMUSG00000075014                        260472.66  ...                                7.05
# ENSMUSG00000106106                         57551.00  ...                           227115.00
# ENSMUSG00000095186                         54814.02  ...                                2.00
# ...                                             ...  ...                                 ...
# ENSMUSG00000118363                             0.00  ...                                0.00
# ENSMUSG00000118365                             0.00  ...                                0.00
# ENSMUSG00000118372                             0.00  ...                                0.00
# ENSMUSG00000118375                             0.00  ...                                0.00
# ENSMUSG00000118381                             0.00  ...                                0.00
#
# [55536 rows x 44 columns]

# %%
#raw_counts_transcripts.to_csv('raw_counts_transcripts_stats.csv')

# %%
# Get ERCC counts
ercc_counts = raw_counts_table[raw_counts_table.index.str.contains('^ERCC-')] 
ercc_counts.reset_index(inplace=True)
ercc_counts = ercc_counts.rename(columns={'Gene_ID':'ERCC ID'})
ercc_counts = ercc_counts.sort_values(by=list(ercc_counts), ascending=False)
ercc_counts.head()
# Out:
#        ERCC ID  ...  Mmus_C57-6T_SPL_FLT_ISS-T_Rep7_F10
# 91  ERCC-00171  ...                                56.0
# 90  ERCC-00170  ...                                 1.0
# 89  ERCC-00168  ...                                 0.0
# 88  ERCC-00165  ...                                 1.0
# 87  ERCC-00164  ...                                 0.0
#
# [5 rows x 45 columns]

# %%
# Get ERCC files
ercc_url = 'https://assets.thermofisher.com/TFS-Assets/LSG/manuals/cms_095046.txt'
filehandle, _ = urlretrieve(ercc_url)
ercc_table = pd.read_csv(filehandle, '\t')
ercc_table.head(n=3)
# Out:
#    Re-sort ID     ERCC ID  ... expected fold-change ratio  log2(Mix 1/Mix 2)
# 0           1  ERCC-00130  ...                        4.0                2.0
# 1           2  ERCC-00004  ...                        4.0                2.0
# 2           3  ERCC-00136  ...                        4.0                2.0
#
# [3 rows x 7 columns]

# %% [markdown]
# ## Number of ERCC Detected
# Number of ERCC detected in each of the 4 (A, B, C and D) groups for the study.

# %% [markdown]
# Filter counts > 0

# %%
meltERCC = ercc_counts.melt(id_vars=['ERCC ID'])
meltERCC['log2 Count'] = meltERCC['value']+1
meltERCC['log2 Count'] = np.log2(meltERCC['log2 Count'])
meltERCC = meltERCC.rename(columns={'variable':'Sample Name', 'value':'Count'})
meltERCC.head(n=3)
# Out:
#       ERCC ID                      Sample Name  Count  log2 Count
# 0  ERCC-00171  Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  134.0    7.076816
# 1  ERCC-00170  Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3    2.0    1.584963
# 2  ERCC-00168  Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3    0.0    0.000000

# %%
# Build Mix dictionary to link sample name to mix added using assay table
mix_dict = assay_table.filter(['Sample Name','Parameter Value[Spike-in Mix number]', 
                       'Parameter Value[Read Depth,http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C155320,NCIT]'])
mix_dict = mix_dict.rename(columns={'Parameter Value[Spike-in Mix number]':'Mix',
                                    'Parameter Value[Read Depth,http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C155320,NCIT]':
                                    'Total Reads'})
mix_dict.head(n=3)
# Out:
#                        Sample Name    Mix  Total Reads
# 0  Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  Mix 1    106545145
# 1  Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  Mix 1    111068823
# 2  Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  Mix 1    110761283

# %%
# Make combined ercc counts and assay table
merged_ercc = meltERCC.merge(mix_dict, on='Sample Name')
merged_ercc.head(n=3)
# Out:
#       ERCC ID                      Sample Name  ...    Mix  Total Reads
# 0  ERCC-00171  Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  ...  Mix 1    106545145
# 1  ERCC-00170  Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  ...  Mix 1    106545145
# 2  ERCC-00168  Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  ...  Mix 1    106545145
#
# [3 rows x 6 columns]

# %%
# Read ERCC info including concentrations from merged_ercc table
groupA = ercc_table.loc[ercc_table['subgroup'] == 'A']['ERCC ID']
groupB = ercc_table.loc[ercc_table['subgroup'] == 'B']['ERCC ID']
groupC = ercc_table.loc[ercc_table['subgroup'] == 'C']['ERCC ID']
groupD = ercc_table.loc[ercc_table['subgroup'] == 'D']['ERCC ID']

# Make a dictionary for ERCC group
group_dict = dict(zip(ercc_table['ERCC ID'], ercc_table['subgroup']))

# %%
# Calculate Count per million and log2 Count per million
merged_ercc['Count per million'] = merged_ercc['Count'] / (merged_ercc['Total Reads'] / 1000000.0)
merged_ercc['log2 Count per million'] = np.log2(merged_ercc['Count per million']+1)

# Add ERCC group
merged_ercc['ERCC group'] = merged_ercc['ERCC ID'].map(group_dict)
merged_ercc
# Out:
#          ERCC ID  ... ERCC group
# 0     ERCC-00171  ...          B
# 1     ERCC-00170  ...          A
# 2     ERCC-00168  ...          D
# 3     ERCC-00165  ...          D
# 4     ERCC-00164  ...          C
# ...          ...  ...        ...
# 4043  ERCC-00012  ...          C
# 4044  ERCC-00009  ...          B
# 4045  ERCC-00004  ...          A
# 4046  ERCC-00003  ...          D
# 4047  ERCC-00002  ...          D
#
# [4048 rows x 9 columns]

# %% [markdown]
# Filter and calculate mean log2 Count per million of Mix1 and Mix2 in each of the 4 groups

# %%
# Filter Mix1 log2 CPM and Mix2 log2 CPM in group A 
# Mean values of Mix1 log2 CPM and Mix2 log2 CPM
Adf = merged_ercc.loc[merged_ercc['ERCC group'] == 'A']

Amix1df = Adf.loc[Adf['Mix']=='Mix 1']
Amix1df['Mix1 log2 CPM'] = Amix1df[Amix1df['log2 Count per million'] > 0]['log2 Count per million'].dropna()
Amix1df = Amix1df.groupby('ERCC ID')['Mix1 log2 CPM'].agg(np.mean).rename('ave Mix1 log2 CPM')
Amix1df = Amix1df.to_frame()
Amix2df = Adf.loc[Adf['Mix']=='Mix 2']
Amix2df['Mix2 log2 CPM'] = Amix2df[Amix2df['log2 Count per million'] > 0]['log2 Count per million'].dropna()
Amix2df = Amix2df.groupby('ERCC ID')['Mix2 log2 CPM'].agg(np.mean).rename('ave Mix2 log2 CPM')
Amix2df = Amix2df.to_frame()

adf = Amix1df.merge(Amix2df, on='ERCC ID', suffixes=('', '_2'))
adf = adf.reset_index()
adf['ave Mix1 log2 CPM/ ave Mix2 log2 CPM'] = (adf['ave Mix1 log2 CPM'] / adf['ave Mix2 log2 CPM'])

# %%
Bdf = merged_ercc.loc[merged_ercc['ERCC group'] == 'B']
Bmix1df = Bdf.loc[Bdf['Mix']=='Mix 1']
Bmix1df['Mix1 log2 CPM'] = Bmix1df[Bmix1df['log2 Count per million'] > 0]['log2 Count per million'].dropna()
Bmix1df = Bmix1df.groupby('ERCC ID')['Mix1 log2 CPM'].agg(np.mean).rename('ave Mix1 log2 CPM')
Bmix1df = Bmix1df.to_frame()
Bmix2df = Bdf.loc[Bdf['Mix']=='Mix 2']
Bmix2df['Mix2 log2 CPM'] = Bmix2df[Bmix2df['log2 Count per million'] > 0]['log2 Count per million'].dropna()
Bmix2df = Bmix2df.groupby('ERCC ID')['Mix2 log2 CPM'].agg(np.mean).rename('ave Mix2 log2 CPM')
Bmix2df = Bmix2df.to_frame()

bdf = Bmix1df.merge(Bmix2df, on='ERCC ID')
bdf = bdf.reset_index()
bdf['ave Mix1 log2 CPM/ ave Mix2 log2 CPM'] = (bdf['ave Mix1 log2 CPM'] / bdf['ave Mix2 log2 CPM'])

# %%
Cdf = merged_ercc.loc[merged_ercc['ERCC group'] == 'C']
Cmix1df = Cdf.loc[Cdf['Mix']=='Mix 1']
Cmix1df['Mix1 log2 CPM'] = Cmix1df[Cmix1df['log2 Count per million'] > 0]['log2 Count per million'].dropna()
Cmix1df = Cmix1df.groupby('ERCC ID')['Mix1 log2 CPM'].agg(np.mean).rename('ave Mix1 log2 CPM')
Cmix1df = Cmix1df.to_frame()
Cmix2df = Cdf.loc[Cdf['Mix']=='Mix 2']
Cmix2df['Mix2 log2 CPM'] = Cmix2df[Cmix2df['log2 Count per million'] > 0]['log2 Count per million'].dropna()
Cmix2df = Cmix2df.groupby('ERCC ID')['Mix2 log2 CPM'].agg(np.mean).rename('ave Mix2 log2 CPM')
Cmix2df = Cmix2df.to_frame()

cdf = Cmix1df.merge(Cmix2df, on='ERCC ID')
cdf = cdf.reset_index()
cdf['ave Mix1 log2 CPM/ ave Mix2 log2 CPM'] = (cdf['ave Mix1 log2 CPM'] / cdf['ave Mix2 log2 CPM'])

# %%
Ddf = merged_ercc.loc[merged_ercc['ERCC group'] == 'D']
Dmix1df = Ddf.loc[Ddf['Mix']=='Mix 1']
Dmix1df['Mix1 log2 CPM'] = Dmix1df[Dmix1df['log2 Count per million'] > 0]['log2 Count per million'].dropna()
Dmix1df = Dmix1df.groupby('ERCC ID')['Mix1 log2 CPM'].agg(np.mean).rename('ave Mix1 log2 CPM')
Dmix1df = Dmix1df.to_frame()
Dmix2df = Ddf.loc[Ddf['Mix']=='Mix 2']
Dmix2df['Mix2 log2 CPM'] = Dmix2df[Dmix2df['log2 Count per million'] > 0]['log2 Count per million'].dropna()
Dmix2df = Dmix2df.groupby('ERCC ID')['Mix2 log2 CPM'].agg(np.mean).rename('ave Mix2 log2 CPM')
Dmix2df = Dmix2df.to_frame()

ddf = Dmix1df.merge(Dmix2df, on='ERCC ID')
ddf = ddf.reset_index()
ddf['ave Mix1 log2 CPM/ ave Mix2 log2 CPM'] = (ddf['ave Mix1 log2 CPM'] / ddf['ave Mix2 log2 CPM'])

# %% [markdown]
# Barplots of number of ERCC detected in group A.

# %%
a = sns.catplot(x="ERCC ID", y="log2 Count per million", order=groupA, hue="Mix",data=merged_ercc[merged_ercc['ERCC ID'].isin(groupA)], kind="box", col="ERCC group", height=5, aspect=1)
a.set_xticklabels(rotation=90)
plt.text(23,1.5,"Mix1/ Mix2 = 4")
#figApath = 'groupA.pdf'
#a.savefig(figApath, bbox_inches='tight')

a = sns.catplot(x="ERCC ID", y="ave Mix1 log2 CPM/ ave Mix2 log2 CPM", palette="rocket_r", data=adf, kind="bar", 
               height=5, aspect=1, linewidth=0.5)
a.set_xticklabels(rotation=90)
plt.title("ERCC Group A")
a.set(ylim=(0, 4))
#figApath = 'groupA1.pdf'
#a.savefig(figApath, bbox_inches='tight')
print('Number of ERCC detected in group A (out of 23) =', adf['ave Mix1 log2 CPM/ ave Mix2 log2 CPM'].count())
# Out:
# Number of ERCC detected in group A (out of 23) = 16

# %% [markdown]
# Barplots of number of ERCC detected in group B.

# %%
b = sns.catplot(x="ERCC ID", y="log2 Count per million", order=groupB, hue="Mix", data=merged_ercc[merged_ercc['ERCC ID'].isin(groupB)], kind="box", col="ERCC group", height=5, aspect=1)
b.set_xticklabels(rotation=90)
plt.text(23,1.25,"Mix1/ Mix2 = 1")

b = sns.catplot(x="ERCC ID", y="ave Mix1 log2 CPM/ ave Mix2 log2 CPM", palette="rocket_r", data=bdf, kind="bar", 
               height=5, aspect=1, linewidth=0.5)
b.set_xticklabels(rotation=90)
plt.title("ERCC Group B")
b.set(ylim=(0, 2))
print('Number of ERCC detected in group B (out of 23) =', bdf['ave Mix1 log2 CPM/ ave Mix2 log2 CPM'].count())
# Out:
# Number of ERCC detected in group B (out of 23) = 14

# %% [markdown]
# Barplots of number of ERCC detected in group C.

# %%
c = sns.catplot(x="ERCC ID", y="log2 Count per million", order=groupC, hue="Mix", data=merged_ercc[merged_ercc['ERCC ID'].isin(groupC)], kind="box", col="ERCC group", height=5, aspect=1)
c.set_xticklabels(rotation=90)
plt.text(23,1.25,"Mix1/ Mix2 = 0.67")

c = sns.catplot(x="ERCC ID", y="ave Mix1 log2 CPM/ ave Mix2 log2 CPM", palette="rocket_r", data=cdf, kind="bar", 
               height=5, aspect=1, linewidth=0.5)
c.set_xticklabels(rotation=90)
plt.title("ERCC Group C")
c.set(ylim=(0, 3))
print('Number of ERCC detected in group C (out of 23) =', cdf['ave Mix1 log2 CPM/ ave Mix2 log2 CPM'].count())
# Out:
# Number of ERCC detected in group C (out of 23) = 15

# %% [markdown]
# Barplots of number of ERCC detected in group D.

# %%
d = sns.catplot(x="ERCC ID", y="log2 Count per million", order=groupD, hue="Mix", data=merged_ercc[merged_ercc['ERCC ID'].isin(groupD)], col="ERCC group", kind="box", height=5, aspect=1)
d.set_xticklabels(rotation=90)
plt.text(23,1.25,"Mix1/ Mix2 = 0.5")

d = sns.catplot(x="ERCC ID", y="ave Mix1 log2 CPM/ ave Mix2 log2 CPM", palette="rocket_r", data=ddf, kind="bar", 
               height=5, aspect=1, linewidth=0.5)
d.set_xticklabels(rotation=90)
plt.title("ERCC Group D")
d.set(ylim=(0, 1.5))
print('Number of ERCC detected in group D (out of 23) =', ddf['ave Mix1 log2 CPM/ ave Mix2 log2 CPM'].count())
# Out:
# Number of ERCC detected in group D (out of 23) = 17

# %% [markdown]
# ## Single Sample ERCC Analysis
# Because samples may be combined by users outside of their original study, it is useful to have ERCC metrics that can be calculated from single samples. These could include: limit of detection, dynamic range, R^2 from measured vs expected plot, etc.

# %%
ercc_table.head(n=3)
# Out:
#    Re-sort ID     ERCC ID  ... expected fold-change ratio  log2(Mix 1/Mix 2)
# 0           1  ERCC-00130  ...                        4.0                2.0
# 1           2  ERCC-00004  ...                        4.0                2.0
# 2           3  ERCC-00136  ...                        4.0                2.0
#
# [3 rows x 7 columns]

# %%
# Make a dictionary for ERCC concentrations for each mix
mix1_conc_dict = dict(zip(ercc_table['ERCC ID'], ercc_table['concentration in Mix 1 (attomoles/ul)']))
mix2_conc_dict = dict(zip(ercc_table['ERCC ID'], ercc_table['concentration in Mix 2 (attomoles/ul)']))

# %% [markdown]
# Sometimes Spike-in Mix Number is spelled Spike-in Mix number.  Check assay_table header if you run into an error in the cell below.

# %%
pd.set_option('max_columns', 80)
assay_table.head(n=3)
# Out:
#                        Sample Name             Protocol REF  \
# 0  Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  nucleic acid extraction
# 1  Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  nucleic acid extraction
# 2  Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  nucleic acid extraction
#
#   Parameter Value[QA Instrument] Parameter Value[QA Assay]  \
# 0       Agilent 2100 Bioanalyzer       RNA 6000 Nano Assay
# 1       Agilent 2100 Bioanalyzer       RNA 6000 Nano Assay
# 2       Agilent 2100 Bioanalyzer       RNA 6000 Nano Assay
#
#    Parameter Value[QA Score]                  Unit Term Source REF  \
# 0                        5.9  RNA Integrity Number            NCIT
# 1                        6.6  RNA Integrity Number            NCIT
# 2                        8.7  RNA Integrity Number            NCIT
#
#                                Term Accession Number  \
# 0  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 1  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 2  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
#
#                       Extract Name     Protocol REF.1  \
# 0  Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  spike-in protocol
# 1  Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  spike-in protocol
# 2  Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  spike-in protocol
#
#   Parameter Value[Spike-in Quality Control]  Term Source REF.1  \
# 0              ERCC ExFold RNA Spike-In Mix                NaN
# 1              ERCC ExFold RNA Spike-In Mix                NaN
# 2              ERCC ExFold RNA Spike-In Mix                NaN
#
#    Term Accession Number.1 Parameter Value[Spike-in Mix number]  \
# 0                      NaN                                Mix 1
# 1                      NaN                                Mix 1
# 2                      NaN                                Mix 1
#
#    Term Source REF.2  Term Accession Number.2        Protocol REF.2  \
# 0                NaN                      NaN  library construction
# 1                NaN                      NaN  library construction
# 2                NaN                      NaN  library construction
#
#   Parameter Value[library selection] Parameter Value[library layout]  \
# 0                     Ribo-depletion                          PAIRED
# 1                     Ribo-depletion                          PAIRED
# 2                     Ribo-depletion                          PAIRED
#
#   Parameter Value[stranded] Parameter Value[Library QA Instrument]  \
# 0                  STRANDED               Agilent 4200 TapeStation
# 1                  STRANDED               Agilent 4200 TapeStation
# 2                  STRANDED               Agilent 4200 TapeStation
#
#    Term Source REF.3  Term Accession Number.3  \
# 0                NaN                      NaN
# 1                NaN                      NaN
# 2                NaN                      NaN
#
#   Parameter Value[Library QA Assay]  Term Source REF.4  \
# 0                  D1000 ScreenTape                NaN
# 1                  D1000 ScreenTape                NaN
# 2                  D1000 ScreenTape                NaN
#
#    Term Accession Number.4  Parameter Value[Fragment Size]     Unit.1  \
# 0                      NaN                             287  base pair
# 1                      NaN                             289  base pair
# 2                      NaN                             283  base pair
#
#   Term Source REF.5                    Term Accession Number.5  \
# 0                UO  http://purl.obolibrary.org/obo/UO_0000244
# 1                UO  http://purl.obolibrary.org/obo/UO_0000244
# 2                UO  http://purl.obolibrary.org/obo/UO_0000244
#
#             Protocol REF.3 Parameter Value[sequencing instrument]  \
# 0  nucleic acid sequencing                  Illumina NovaSeq 6000
# 1  nucleic acid sequencing                  Illumina NovaSeq 6000
# 2  nucleic acid sequencing                  Illumina NovaSeq 6000
#
#   Parameter Value[base caller]  \
# 0                    bcl2fastq
# 1                    bcl2fastq
# 2                    bcl2fastq
#
#    Parameter Value[Read Length,http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C153362,NCIT]  \
# 0                                                149
# 1                                                149
# 2                                                149
#
#       Unit.2 Term Source REF.6                    Term Accession Number.6  \
# 0  base pair                UO  http://purl.obolibrary.org/obo/UO_0000244
# 1  base pair                UO  http://purl.obolibrary.org/obo/UO_0000244
# 2  base pair                UO  http://purl.obolibrary.org/obo/UO_0000244
#
#   Assay Name  Parameter Value[rRNA Contamination]   Unit.3  ...  \
# 0    rna-seq                                 0.85  percent  ...
# 1    rna-seq                                 0.35  percent  ...
# 2    rna-seq                                 1.04  percent  ...
#
#                      Term Accession Number.7  \
# 0  http://purl.obolibrary.org/obo/UO_0000187
# 1  http://purl.obolibrary.org/obo/UO_0000187
# 2  http://purl.obolibrary.org/obo/UO_0000187
#
#   Parameter Value[Read Depth,http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C155320,NCIT]  \
# 0                                          106545145
# 1                                          111068823
# 2                                          110761283
#
#    Unit.4 Term Source REF.8                    Term Accession Number.8  \
# 0    read                SO  http://purl.obolibrary.org/obo/SO_0000150
# 1    read                SO  http://purl.obolibrary.org/obo/SO_0000150
# 2    read                SO  http://purl.obolibrary.org/obo/SO_0000150
#
#                                        Raw Data File  \
# 0  GLDS-246_rna-seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...
# 1  GLDS-246_rna-seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...
# 2  GLDS-246_rna-seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...
#
#                   Parameter Value[Fastqc File Names] Term Source REF.9  \
# 0  GLDS-246_rna-seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...               NaN
# 1  GLDS-246_rna-seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...               NaN
# 2  GLDS-246_rna-seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...               NaN
#
#    Term Accession Number.9                Parameter Value[Multiqc File Names]  \
# 0                      NaN  GLDS-246_rna-seq_raw_multiqc_report.html, GLDS...
# 1                      NaN  GLDS-246_rna-seq_raw_multiqc_report.html, GLDS...
# 2                      NaN  GLDS-246_rna-seq_raw_multiqc_report.html, GLDS...
#
#   Term Source REF.10  Term Accession Number.10  \
# 0                NaN                       NaN
# 1                NaN                       NaN
# 2                NaN                       NaN
#
#                             Protocol REF.4  \
# 0  GeneLab RNAseq data processing protocol
# 1  GeneLab RNAseq data processing protocol
# 2  GeneLab RNAseq data processing protocol
#
#   Parameter Value[trimmed sequence data,http://purl.obolibrary.org/obo/OBI_0002569,OBI]  \
# 0  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...
# 1  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...
# 2  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...
#
#   Term Source REF.11  Term Accession Number.11  \
# 0                NaN                       NaN
# 1                NaN                       NaN
# 2                NaN                       NaN
#
#    Parameter Value[Trimmed Sequence Data Fastqc File] Term Source REF.12  \
# 0  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...                 NaN
# 1  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...                 NaN
# 2  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...                 NaN
#
#    Term Accession Number.12  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
#
#    Parameter Value[Trimmed Sequence Data Multiqc File] Term Source REF.13  \
# 0  GLDS-246_rna_seq_trimmed_multiqc_report.html, ...                  NaN
# 1  GLDS-246_rna_seq_trimmed_multiqc_report.html, ...                  NaN
# 2  GLDS-246_rna_seq_trimmed_multiqc_report.html, ...                  NaN
#
#    Term Accession Number.13  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
#
#                      Parameter Value[Trimmed Report] Term Source REF.14  \
# 0  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...                NaN
# 1  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...                NaN
# 2  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...                NaN
#
#    Term Accession Number.14  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
#
#    Parameter Value[aligned sequence data,http://purl.obolibrary.org/obo/OBI_0002580,OBI]  \
# 0  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...
# 1  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...
# 2  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...
#
#   Term Source REF.15  Term Accession Number.15  \
# 0                NaN                       NaN
# 1                NaN                       NaN
# 2                NaN                       NaN
#
#                      Parameter Value[Alignment Logs] Term Source REF.16  \
# 0  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...                NaN
# 1  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...                NaN
# 2  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...                NaN
#
#    Term Accession Number.16  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
#
#                Parameter Value[Raw Counts Data File] Term Source REF.17  \
# 0  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...                NaN
# 1  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...                NaN
# 2  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...                NaN
#
#    Term Accession Number.17  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
#
#         Parameter Value[Normalized Counts Data File] Term Source REF.18  \
# 0  GLDS-246_rna_seq_Normalized_Counts.csv, GLDS-2...                NaN
# 1  GLDS-246_rna_seq_Normalized_Counts.csv, GLDS-2...                NaN
# 2  GLDS-246_rna_seq_Normalized_Counts.csv, GLDS-2...                NaN
#
#    Term Accession Number.18  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
#
#    Parameter Value[differential expression analysis data transformation,http://purl.obolibrary.org/obo/OBI_0000650,OBI]  \
# 0  GLDS-246_rna_seq_contrasts.csv, GLDS-246_rna_s...
# 1  GLDS-246_rna_seq_contrasts.csv, GLDS-246_rna_s...
# 2  GLDS-246_rna_seq_contrasts.csv, GLDS-246_rna_s...
#
#   Term Source REF.19  Term Accession Number.19
# 0                NaN                       NaN
# 1                NaN                       NaN
# 2                NaN                       NaN
#
# [3 rows x 81 columns]

# %%
# get samples that use mix 1 and mix 2
mix1_samples = assay_table[assay_table['Parameter Value[Spike-in Mix number]'] == 'Mix 1']['Sample Name']
mix2_samples = assay_table[assay_table['Parameter Value[Spike-in Mix number]'] == 'Mix 2']['Sample Name']

# %%
# Get ERCC counts
ercc_counts = raw_counts_table[raw_counts_table.index.str.contains('^ERCC-')] 
ercc_counts = ercc_counts.sort_values(by=list(ercc_counts), ascending=False)
ercc_counts.head()
# Out:
#             Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  \
# Gene_ID
# ERCC-00130                           2576.0                           1765.0
# ERCC-00096                            958.0                            701.0
# ERCC-00002                            769.0                            533.0
# ERCC-00074                            692.0                            383.0
# ERCC-00004                            215.0                            111.0
#
#             Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  Mmus_C57-6T_SPL_BSL_LAR_Rep4_B6  \
# Gene_ID
# ERCC-00130                           5596.0                           1782.0
# ERCC-00096                           1915.0                            504.0
# ERCC-00002                           1888.0                            456.0
# ERCC-00074                           1553.0                            294.0
# ERCC-00004                            606.0                             97.0
#
#             Mmus_C57-6T_SPL_BSL_LAR_Rep5_B7  Mmus_C57-6T_SPL_BSL_LAR_Rep6_B8  \
# Gene_ID
# ERCC-00130                           1081.0                           1081.0
# ERCC-00096                            259.0                            262.0
# ERCC-00002                            212.0                            163.0
# ERCC-00074                            237.0                            307.0
# ERCC-00004                             94.0                            138.0
#
#             Mmus_C57-6T_SPL_BSL_LAR_Rep7_B9  Mmus_C57-6T_SPL_BSL_LAR_Rep8_B10  \
# Gene_ID
# ERCC-00130                           2595.0                             130.0
# ERCC-00096                            855.0                              21.0
# ERCC-00002                            735.0                              17.0
# ERCC-00074                            564.0                             191.0
# ERCC-00004                            227.0                              67.0
#
#             Mmus_C57-6T_SPL_BSL_LAR_Rep9_B1  Mmus_C57-6T_SPL_BSL_LAR_Rep10_B2  \
# Gene_ID
# ERCC-00130                            829.0                            1167.0
# ERCC-00096                            267.0                             303.0
# ERCC-00002                            211.0                             240.0
# ERCC-00074                            189.0                             220.0
# ERCC-00004                             51.0                              82.0
#
#             Mmus_C57-6T_SPL_GC_LAR_Rep1_G3  Mmus_C57-6T_SPL_GC_LAR_Rep2_G4  \
# Gene_ID
# ERCC-00130                          3765.0                          3152.0
# ERCC-00096                          1366.0                          1109.0
# ERCC-00002                          1244.0                          1102.0
# ERCC-00074                           872.0                           885.0
# ERCC-00004                           279.0                           316.0
#
#             Mmus_C57-6T_SPL_GC_LAR_Rep3_G5  Mmus_C57-6T_SPL_GC_LAR_Rep4_G6  \
# Gene_ID
# ERCC-00130                           588.0                          2270.0
# ERCC-00096                           146.0                           688.0
# ERCC-00002                           102.0                           621.0
# ERCC-00074                           179.0                           446.0
# ERCC-00004                            90.0                           148.0
#
#             Mmus_C57-6T_SPL_GC_LAR_Rep5_G7  Mmus_C57-6T_SPL_GC_LAR_Rep6_G8  \
# Gene_ID
# ERCC-00130                          3869.0                          3882.0
# ERCC-00096                          1348.0                          1408.0
# ERCC-00002                          1209.0                          1245.0
# ERCC-00074                          1061.0                          1085.0
# ERCC-00004                           371.0                           347.0
#
#             Mmus_C57-6T_SPL_GC_LAR_Rep7_G9  Mmus_C57-6T_SPL_GC_LAR_Rep8_G10  \
# Gene_ID
# ERCC-00130                           953.0                           1295.0
# ERCC-00096                           246.0                            467.0
# ERCC-00002                           213.0                            327.0
# ERCC-00074                           182.0                            280.0
# ERCC-00004                            49.0                            105.0
#
#             Mmus_C57-6T_SPL_GC_LAR_Rep9_G2  Mmus_C57-6T_SPL_FLT_LAR_Rep1_F3  \
# Gene_ID
# ERCC-00130                          1699.0                            371.0
# ERCC-00096                           500.0                            484.0
# ERCC-00002                           412.0                            809.0
# ERCC-00074                           383.0                            308.0
# ERCC-00004                           145.0                             15.0
#
#             Mmus_C57-6T_SPL_FLT_LAR_Rep2_F4  Mmus_C57-6T_SPL_FLT_LAR_Rep3_F5  \
# Gene_ID
# ERCC-00130                           1047.0                            268.0
# ERCC-00096                           1376.0                            307.0
# ERCC-00002                           2688.0                            367.0
# ERCC-00074                           1482.0                            402.0
# ERCC-00004                             98.0                             27.0
#
#             Mmus_C57-6T_SPL_FLT_LAR_Rep4_F6  Mmus_C57-6T_SPL_FLT_LAR_Rep5_F7  \
# Gene_ID
# ERCC-00130                           1533.0                            388.0
# ERCC-00096                           2328.0                            476.0
# ERCC-00002                           4336.0                            731.0
# ERCC-00074                           2508.0                            390.0
# ERCC-00004                            150.0                             23.0
#
#             Mmus_C57-6T_SPL_FLT_LAR_Rep6_F8  Mmus_C57-6T_SPL_FLT_LAR_Rep7_F9  \
# Gene_ID
# ERCC-00130                            894.0                            211.0
# ERCC-00096                           1282.0                            268.0
# ERCC-00002                           2421.0                            430.0
# ERCC-00074                           1565.0                            306.0
# ERCC-00004                            102.0                             15.0
#
#             Mmus_C57-6T_SPL_FLT_LAR_Rep8_F10  \
# Gene_ID
# ERCC-00130                             213.0
# ERCC-00096                             252.0
# ERCC-00002                             396.0
# ERCC-00074                             297.0
# ERCC-00004                              11.0
#
#             Mmus_C57-6T_SPL_BSL_ISS-T_Rep1_B6  \
# Gene_ID
# ERCC-00130                              775.0
# ERCC-00096                             1058.0
# ERCC-00002                             1800.0
# ERCC-00074                             1193.0
# ERCC-00004                               83.0
#
#             Mmus_C57-6T_SPL_BSL_ISS-T_Rep2_B7  \
# Gene_ID
# ERCC-00130                             1404.0
# ERCC-00096                             1931.0
# ERCC-00002                             3571.0
# ERCC-00074                             3099.0
# ERCC-00004                              173.0
#
#             Mmus_C57-6T_SPL_BSL_ISS-T_Rep3_B8  \
# Gene_ID
# ERCC-00130                              479.0
# ERCC-00096                              582.0
# ERCC-00002                              832.0
# ERCC-00074                              504.0
# ERCC-00004                               28.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep1_G3  \
# Gene_ID
# ERCC-00130                            1143.0
# ERCC-00096                            1709.0
# ERCC-00002                            3009.0
# ERCC-00074                            1551.0
# ERCC-00004                              75.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep2_G4  \
# Gene_ID
# ERCC-00130                             988.0
# ERCC-00096                            1366.0
# ERCC-00002                            2708.0
# ERCC-00074                            1343.0
# ERCC-00004                              70.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep3_G5  \
# Gene_ID
# ERCC-00130                            2341.0
# ERCC-00096                            3595.0
# ERCC-00002                            6732.0
# ERCC-00074                            4336.0
# ERCC-00004                             234.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep4_G6  \
# Gene_ID
# ERCC-00130                            1267.0
# ERCC-00096                            1843.0
# ERCC-00002                            3034.0
# ERCC-00074                            1734.0
# ERCC-00004                              83.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep5_G8  \
# Gene_ID
# ERCC-00130                            1647.0
# ERCC-00096                            2582.0
# ERCC-00002                            4129.0
# ERCC-00074                            2430.0
# ERCC-00004                             143.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep6_G9  \
# Gene_ID
# ERCC-00130                             308.0
# ERCC-00096                             364.0
# ERCC-00002                             487.0
# ERCC-00074                             417.0
# ERCC-00004                              26.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep7_G10  \
# Gene_ID
# ERCC-00130                              422.0
# ERCC-00096                              594.0
# ERCC-00002                              784.0
# ERCC-00074                              633.0
# ERCC-00004                               29.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep1_F3  \
# Gene_ID
# ERCC-00130                             4782.0
# ERCC-00096                             1603.0
# ERCC-00002                             1615.0
# ERCC-00074                             1571.0
# ERCC-00004                              539.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep2_F4  \
# Gene_ID
# ERCC-00130                             5218.0
# ERCC-00096                             1777.0
# ERCC-00002                             1737.0
# ERCC-00074                             1401.0
# ERCC-00004                              512.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep3_F5  \
# Gene_ID
# ERCC-00130                             5851.0
# ERCC-00096                             2203.0
# ERCC-00002                             1842.0
# ERCC-00074                             1430.0
# ERCC-00004                              545.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep4_F7  \
# Gene_ID
# ERCC-00130                             6375.0
# ERCC-00096                             2235.0
# ERCC-00002                             1713.0
# ERCC-00074                             1222.0
# ERCC-00004                              443.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep5_F8  \
# Gene_ID
# ERCC-00130                             1855.0
# ERCC-00096                              518.0
# ERCC-00002                              323.0
# ERCC-00074                              383.0
# ERCC-00004                              142.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep6_F9  \
# Gene_ID
# ERCC-00130                             1387.0
# ERCC-00096                              416.0
# ERCC-00002                              329.0
# ERCC-00074                              210.0
# ERCC-00004                               76.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep7_F10
# Gene_ID
# ERCC-00130                              1568.0
# ERCC-00096                               460.0
# ERCC-00002                               319.0
# ERCC-00074                               377.0
# ERCC-00004                               137.0

# %%
ercc_counts_mix_1 = ercc_counts[mix1_samples]
ercc_counts_mix_1['ERCC conc (attomoles/ul)'] = ercc_counts_mix_1.index.map(mix1_conc_dict)
ercc_counts_mix_1.head(n=3)
# Out:
#             Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  \
# Gene_ID
# ERCC-00130                           2576.0                           1765.0
# ERCC-00096                            958.0                            701.0
# ERCC-00002                            769.0                            533.0
#
#             Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  Mmus_C57-6T_SPL_BSL_LAR_Rep4_B6  \
# Gene_ID
# ERCC-00130                           5596.0                           1782.0
# ERCC-00096                           1915.0                            504.0
# ERCC-00002                           1888.0                            456.0
#
#             Mmus_C57-6T_SPL_BSL_LAR_Rep5_B7  Mmus_C57-6T_SPL_BSL_LAR_Rep6_B8  \
# Gene_ID
# ERCC-00130                           1081.0                           1081.0
# ERCC-00096                            259.0                            262.0
# ERCC-00002                            212.0                            163.0
#
#             Mmus_C57-6T_SPL_BSL_LAR_Rep7_B9  Mmus_C57-6T_SPL_BSL_LAR_Rep8_B10  \
# Gene_ID
# ERCC-00130                           2595.0                             130.0
# ERCC-00096                            855.0                              21.0
# ERCC-00002                            735.0                              17.0
#
#             Mmus_C57-6T_SPL_BSL_LAR_Rep9_B1  Mmus_C57-6T_SPL_BSL_LAR_Rep10_B2  \
# Gene_ID
# ERCC-00130                            829.0                            1167.0
# ERCC-00096                            267.0                             303.0
# ERCC-00002                            211.0                             240.0
#
#             Mmus_C57-6T_SPL_GC_LAR_Rep1_G3  Mmus_C57-6T_SPL_GC_LAR_Rep2_G4  \
# Gene_ID
# ERCC-00130                          3765.0                          3152.0
# ERCC-00096                          1366.0                          1109.0
# ERCC-00002                          1244.0                          1102.0
#
#             Mmus_C57-6T_SPL_GC_LAR_Rep3_G5  Mmus_C57-6T_SPL_GC_LAR_Rep4_G6  \
# Gene_ID
# ERCC-00130                           588.0                          2270.0
# ERCC-00096                           146.0                           688.0
# ERCC-00002                           102.0                           621.0
#
#             Mmus_C57-6T_SPL_GC_LAR_Rep5_G7  Mmus_C57-6T_SPL_GC_LAR_Rep6_G8  \
# Gene_ID
# ERCC-00130                          3869.0                          3882.0
# ERCC-00096                          1348.0                          1408.0
# ERCC-00002                          1209.0                          1245.0
#
#             Mmus_C57-6T_SPL_GC_LAR_Rep7_G9  Mmus_C57-6T_SPL_GC_LAR_Rep8_G10  \
# Gene_ID
# ERCC-00130                           953.0                           1295.0
# ERCC-00096                           246.0                            467.0
# ERCC-00002                           213.0                            327.0
#
#             Mmus_C57-6T_SPL_GC_LAR_Rep9_G2  Mmus_C57-6T_SPL_FLT_ISS-T_Rep1_F3  \
# Gene_ID
# ERCC-00130                          1699.0                             4782.0
# ERCC-00096                           500.0                             1603.0
# ERCC-00002                           412.0                             1615.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep2_F4  \
# Gene_ID
# ERCC-00130                             5218.0
# ERCC-00096                             1777.0
# ERCC-00002                             1737.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep3_F5  \
# Gene_ID
# ERCC-00130                             5851.0
# ERCC-00096                             2203.0
# ERCC-00002                             1842.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep4_F7  \
# Gene_ID
# ERCC-00130                             6375.0
# ERCC-00096                             2235.0
# ERCC-00002                             1713.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep5_F8  \
# Gene_ID
# ERCC-00130                             1855.0
# ERCC-00096                              518.0
# ERCC-00002                              323.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep6_F9  \
# Gene_ID
# ERCC-00130                             1387.0
# ERCC-00096                              416.0
# ERCC-00002                              329.0
#
#             Mmus_C57-6T_SPL_FLT_ISS-T_Rep7_F10  ERCC conc (attomoles/ul)
# Gene_ID
# ERCC-00130                              1568.0                   30000.0
# ERCC-00096                               460.0                   15000.0
# ERCC-00002                               319.0                   15000.0

# %%
ercc_counts_mix_2 = ercc_counts[mix2_samples]
ercc_counts_mix_2['ERCC conc (attomoles/ul)'] = ercc_counts_mix_2.index.map(mix2_conc_dict)
ercc_counts_mix_2.head(n=3)
# Out:
#             Mmus_C57-6T_SPL_FLT_LAR_Rep1_F3  Mmus_C57-6T_SPL_FLT_LAR_Rep2_F4  \
# Gene_ID
# ERCC-00130                            371.0                           1047.0
# ERCC-00096                            484.0                           1376.0
# ERCC-00002                            809.0                           2688.0
#
#             Mmus_C57-6T_SPL_FLT_LAR_Rep3_F5  Mmus_C57-6T_SPL_FLT_LAR_Rep4_F6  \
# Gene_ID
# ERCC-00130                            268.0                           1533.0
# ERCC-00096                            307.0                           2328.0
# ERCC-00002                            367.0                           4336.0
#
#             Mmus_C57-6T_SPL_FLT_LAR_Rep5_F7  Mmus_C57-6T_SPL_FLT_LAR_Rep6_F8  \
# Gene_ID
# ERCC-00130                            388.0                            894.0
# ERCC-00096                            476.0                           1282.0
# ERCC-00002                            731.0                           2421.0
#
#             Mmus_C57-6T_SPL_FLT_LAR_Rep7_F9  Mmus_C57-6T_SPL_FLT_LAR_Rep8_F10  \
# Gene_ID
# ERCC-00130                            211.0                             213.0
# ERCC-00096                            268.0                             252.0
# ERCC-00002                            430.0                             396.0
#
#             Mmus_C57-6T_SPL_BSL_ISS-T_Rep1_B6  \
# Gene_ID
# ERCC-00130                              775.0
# ERCC-00096                             1058.0
# ERCC-00002                             1800.0
#
#             Mmus_C57-6T_SPL_BSL_ISS-T_Rep2_B7  \
# Gene_ID
# ERCC-00130                             1404.0
# ERCC-00096                             1931.0
# ERCC-00002                             3571.0
#
#             Mmus_C57-6T_SPL_BSL_ISS-T_Rep3_B8  \
# Gene_ID
# ERCC-00130                              479.0
# ERCC-00096                              582.0
# ERCC-00002                              832.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep1_G3  \
# Gene_ID
# ERCC-00130                            1143.0
# ERCC-00096                            1709.0
# ERCC-00002                            3009.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep2_G4  \
# Gene_ID
# ERCC-00130                             988.0
# ERCC-00096                            1366.0
# ERCC-00002                            2708.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep3_G5  \
# Gene_ID
# ERCC-00130                            2341.0
# ERCC-00096                            3595.0
# ERCC-00002                            6732.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep4_G6  \
# Gene_ID
# ERCC-00130                            1267.0
# ERCC-00096                            1843.0
# ERCC-00002                            3034.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep5_G8  \
# Gene_ID
# ERCC-00130                            1647.0
# ERCC-00096                            2582.0
# ERCC-00002                            4129.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep6_G9  \
# Gene_ID
# ERCC-00130                             308.0
# ERCC-00096                             364.0
# ERCC-00002                             487.0
#
#             Mmus_C57-6T_SPL_GC_ISS-T_Rep7_G10  ERCC conc (attomoles/ul)
# Gene_ID
# ERCC-00130                              422.0                    7500.0
# ERCC-00096                              594.0                   15000.0
# ERCC-00002                              784.0                   30000.0

# %% [markdown]
# Each sample, either Mix 1 or Mix 2, plotted using scatter plot with x = log2 ERCC conc (attomoles/ ul) and y = log2 Counts.

# %%
columns_mix_1 = ercc_counts_mix_1.columns
columns_mix_2 = ercc_counts_mix_2.columns
all_columns = columns_mix_1.to_list() + columns_mix_2.to_list()
total_columns = len(columns_mix_1) + len(columns_mix_2) - 2
side_size = np.int32(np.ceil(np.sqrt(total_columns)))# calculate grid side size. take sqrt of total plots and round up.
fig, axs = plt.subplots(side_size, side_size, figsize=(20,20), sharex='all', sharey='all'); #change figsize x,y labels if needed.
fig.tight_layout(pad=1, w_pad=2.5, h_pad=3.5)

counter = 0
for ax in axs.flat:
    
    if(counter < len(columns_mix_1)-1):
      ax.scatter(x=np.log2(ercc_counts_mix_1['ERCC conc (attomoles/ul)']), y=np.log2(ercc_counts_mix_1[all_columns[counter]]+1), s=7);
      ax.set_title(all_columns[counter][-45:], fontsize=7.6);
      ax.set_xlabel('log2 ERCC conc (attomoles/ ul)', fontsize=7.5);
      ax.set_ylabel('log2 Counts', fontsize=7.5);
      ax.tick_params(direction='in', axis='both', labelsize=8, labelleft=True, labelbottom=True);
      
    elif(counter >= len(columns_mix_1) and counter < total_columns):
      ax.scatter(x=np.log2(ercc_counts_mix_2['ERCC conc (attomoles/ul)']), y=np.log2(ercc_counts_mix_2[all_columns[counter]]+1), s=7);
      ax.set_title(all_columns[counter][-45:], fontsize=7.6);
      ax.set_xlabel('log2 ERCC conc (attomoles/ ul)', fontsize=7.5);
      ax.set_ylabel('log2 Counts', fontsize=7.5);
      ax.tick_params(direction='in', axis='both', labelsize=8, labelleft=True, labelbottom=True);
       
    else:
      pass

    counter = counter + 1

# %% [markdown]
# Filter counts > 0

# %%
nonzero_counts_list_1 = []
for i in range(0, len(ercc_counts_mix_1.columns)-1):
  counts = ercc_counts_mix_1[columns_mix_1[i]]
  counts.index.rename('Gene_ID', inplace=True)
  countsdf = pd.DataFrame(counts)
  nonzero_counts = countsdf[ercc_counts_mix_1[columns_mix_1[i]] > 0.0]
  nonzero_counts['Conc'] = nonzero_counts.index.map(mix1_conc_dict)
  nonzero_counts.columns = ['Counts','Conc']
  nonzero_counts_sorted = nonzero_counts.sort_values('Conc')
  nonzero_counts_list_1.append(nonzero_counts_sorted)

nonzero_counts_list_2 = []
for i in range(0, len(ercc_counts_mix_2.columns)-1):
  counts = ercc_counts_mix_2[columns_mix_2[i]]
  counts.index.rename('Gene_ID', inplace=True)
  countsdf = pd.DataFrame(counts)
  nonzero_counts = countsdf[ercc_counts_mix_2[columns_mix_2[i]] > 0.0]
  nonzero_counts['Conc'] = nonzero_counts.index.map(mix2_conc_dict)
  nonzero_counts.columns = ['Counts','Conc']
  nonzero_counts_sorted = nonzero_counts.sort_values('Conc')
  nonzero_counts_list_2.append(nonzero_counts_sorted)

# %% [markdown]
# Each sample plotted using linear regression of scatter plot with x = log2 Conc and y = log2 Counts.  Return min, max, R^2 and dynamic range (max / min) values.

# %%
samples = []
mins = []
maxs = []
dyranges = []
rs = []

fig, axs = plt.subplots(side_size, side_size, figsize=(25,20), sharex='all', sharey='all');
fig.tight_layout(pad=1, w_pad=2.5, h_pad=3.5)

counter = 0
list2counter = 0
for ax in axs.flat:
    
    if(counter < len(columns_mix_1)-1):

      nonzero_counts = nonzero_counts_list_1[counter]
      xvalues = nonzero_counts['Conc']
      yvalues = nonzero_counts['Counts']

      sns.regplot(x=np.log2(xvalues), y=np.log2(yvalues), ax=ax);
      ax.set_title(all_columns[counter][-47:], fontsize=8);
      ax.set_xlabel('log2 Conc (attomoles/ul)', fontsize=8);
      ax.set_ylabel('log2 Counts', fontsize=8);
      ax.tick_params(direction='in', axis='both', labelsize=8, labelleft=True, labelbottom=True)
      samples.append(all_columns[counter])

      if(len(xvalues) == 0):
        mins.append('NaN')
        maxs.append('NaN')
        dyranges.append('NaN')
        rs.append('NaN')

    
      else:
        min = xvalues[0];
        mins.append(min)
        minimum = f'Min:{min:.1f}';
        max = xvalues[-1];
        maxs.append(max)
        maximum = f'Max:{max:.1f}';
        dynamic_range = max / min;
        dyranges.append(dynamic_range)
        dyn_str = f'Dyn:{dynamic_range:.1f}';

        ax.text(0.02, 0.98, minimum,
        verticalalignment='top', horizontalalignment='left',
        transform=ax.transAxes,
        color='black', fontsize=10);
      
        ax.text(0.02, 0.88, maximum,
        verticalalignment='top', horizontalalignment='left',
        transform=ax.transAxes,
        color='black', fontsize=10);
      
        ax.text(0.02, 0.78, dyn_str,verticalalignment='top',
                horizontalalignment='left',transform=ax.transAxes,
                color='black', fontsize=10);
      
        if(len(xvalues) == 1):
          rs.append('NaN')

        else:
          slope, intercept, r, p, se = linregress(np.log2(xvalues), y=np.log2(yvalues))
          r_str = f'R:{r:.2f}'
          rs.append(r)

          ax.text(0.02, 0.68, r_str, verticalalignment='top',
                  horizontalalignment='left',transform=ax.transAxes,
                  color='black', fontsize=10);
    
    elif(counter >= len(columns_mix_1) and counter < total_columns):
      
      nonzero_counts = nonzero_counts_list_2[list2counter]
      xvalues = nonzero_counts['Conc']
      yvalues = nonzero_counts['Counts']

      sns.regplot(x=np.log2(xvalues), y=np.log2(yvalues), ax=ax);
      ax.set_title(all_columns[counter][-47:], fontsize=8);
      ax.set_xlabel('log2 Conc (attomoles/ul)', fontsize=8);
      ax.set_ylabel('log2 Counts', fontsize=8);
      ax.tick_params(direction='in', axis='both', labelsize=8, labelleft=True, labelbottom=True);
      samples.append(all_columns[counter])


      if(len(xvalues) == 0):
        mins.append('NaN')
        maxs.append('NaN')
        dyranges.append('NaN')
        rs.append('NaN')
    
      else:
        min = xvalues[0];
        mins.append(min)
        minimum = f'Min:{min:.1f}';
        max = xvalues[-1];
        maxs.append(max)
        maximum = f'Max:{max:.1f}';
        dynamic_range = max / min;
        dyranges.append(dynamic_range)
        dyn_str = f'Dyn:{dynamic_range:.1f}';

        ax.text(0.02, 0.98, minimum,
        verticalalignment='top', horizontalalignment='left',
        transform=ax.transAxes,
        color='black', fontsize=10);
      
        ax.text(0.02, 0.88, maximum,
        verticalalignment='top', horizontalalignment='left',
        transform=ax.transAxes,
        color='black', fontsize=10);
      
        ax.text(0.02, 0.78, dyn_str,verticalalignment='top',
                horizontalalignment='left',transform=ax.transAxes,
                color='black', fontsize=10);
      
        if(len(xvalues) == 1):
          rs.append('NaN')
          
        else:
          slope, intercept, r, p, se = linregress(np.log2(xvalues), y=np.log2(yvalues));
          r_str = f'R:{r:.2f}';
          rs.append(r)

          ax.text(0.02, 0.68, r_str, verticalalignment='top',
                  horizontalalignment='left',transform=ax.transAxes,
                  color='black', fontsize=10);

      list2counter = list2counter + 1
    
    else:
      pass

    counter = counter + 1

# %%
# Directory for saved files
# %mkdir ERCC
# Out:
# mkdir: cannot create directory ‘ERCC’: File exists

# %% [markdown]
# Change to working GLDS# in the following files.

# %%
# Remember to change file names to GLDS# analyzing
# Select files w/ suffix _mqc* prepare for MultiQC report 
stats = pd.DataFrame(list(zip(samples, mins, maxs, dyranges, rs)))
stats.columns = ['Samples', 'Min', 'Max', 'Dynamic range', 'R']
stats.to_csv('ERCC/ERCC_stats_GLDS-246.csv', index = False) 
stats.filter(items = ['Samples', 'Dynamic range']).to_csv('ERCC/ERCC_dynrange_GLDS-246_mqc.csv', index = False)
stats.filter(items = ['Samples', 'R']).to_csv('ERCC/ERCC_rsq_GLDS-246_mqc.csv', index = False)

# %% [markdown]
# ## GeneLab Study Level ERCC
# This section shows an example of how the ERCC spike-ins can be used to assess the power of comparisons within a single study.
#
# In certain studies ERCC Mix 1 and Mix 2 are distributed so that all samples in Group 1 (e.g. Spaceflight) have Mix 1 and all samples in Group 2 (e.g. Ground Control). As certain transcripts in Mix 1 and Mix 2 are present at a known ratio, we can determine how well these patterns are revealed in the dataset.

# %%
combined = sample_table.merge(assay_table, on='Sample Name')
combined = combined.set_index(combined['Sample Name'])
pd.set_option('max_columns', None)
combined.head(n=3)
# Out:
#                                      Source Name Comment[LSDA Source Name]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  LAR Baseline 3                       3B18
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4   LAR Baseline 4                      7870
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5   LAR Baseline 5                      7318
#
#                                  Comment[LSDA Biospecimen Subject ID]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                                   598
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                                   598
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                                   598
#
#                                  Comment[LSDA Biospecimen ID]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                          5910
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                          5910
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                          5910
#
#                                    Protocol REF_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  mouse habitation
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  mouse habitation
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  mouse habitation
#
#                                                      Sample Name  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5
#
#                                 Characteristics[Organism] Term Source REF_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3              Mus musculus         NCBITAXON
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4              Mus musculus         NCBITAXON
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5              Mus musculus         NCBITAXON
#
#                                                            Term Accession Number_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://purl.bioontology.org/ontology/NCBITAXON...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://purl.bioontology.org/ontology/NCBITAXON...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://purl.bioontology.org/ontology/NCBITAXON...
#
#                                 Characteristics[Strain]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3             C57BL/6NTac
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4             C57BL/6NTac
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5             C57BL/6NTac
#
#                                 Comment[Animal Source]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3    Taconic Biosciences
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4    Taconic Biosciences
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5    Taconic Biosciences
#
#                                 Characteristics[sex,http://purl.obolibrary.org/obo/PATO_0000047,EFO]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                                             female
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                                             female
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                                             female
#
#                                 Term Source REF.1_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                 EFO
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                 EFO
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                 EFO
#
#                                                    Term Accession Number.1_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://purl.obolibrary.org/obo/PATO_0000383
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://purl.obolibrary.org/obo/PATO_0000383
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://purl.obolibrary.org/obo/PATO_0000383
#
#                                  Characteristics[Age at Launch] Unit_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                              36   week
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                              36   week
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                              36   week
#
#                                 Term Source REF.2_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  UO
#
#                                                  Term Accession Number.2_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://purl.obolibrary.org/obo/UO_0000034
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://purl.obolibrary.org/obo/UO_0000034
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://purl.obolibrary.org/obo/UO_0000034
#
#                                 Characteristics[Diet,http://purl.bioontology.org/ontology/MESH/D004032,MESH]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3          Nutrient Upgraded Rodent Food Bar (NuRFB)
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4          Nutrient Upgraded Rodent Food Bar (NuRFB)
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5          Nutrient Upgraded Rodent Food Bar (NuRFB)
#
#                                  Term Source REF.3_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  NaN
#
#                                  Term Accession Number.3_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                        NaN
#
#                                 Comment[Feeding Schedule]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                ad libitum
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                ad libitum
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                ad libitum
#
#                                 Factor Value[Spaceflight] Term Source REF.4_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3             Basal Control                 NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4             Basal Control                 NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5             Basal Control                 NaN
#
#                                 Term Accession Number.4_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                       NaN
#
#                                 Factor Value[Duration] Unit.1_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                      1      day
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                      1      day
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                      1      day
#
#                                 Term Source REF.5_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  UO
#
#                                                  Term Accession Number.5_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://purl.obolibrary.org/obo/UO_0000033
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://purl.obolibrary.org/obo/UO_0000033
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://purl.obolibrary.org/obo/UO_0000033
#
#                                 Factor Value[Euthanasia]  Term Source REF.6_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                 On Earth                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                 On Earth                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                 On Earth                  NaN
#
#                                  Term Accession Number.6_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                        NaN
#
#                                 Factor Value[Dissection Condition]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                    Upon euthanasia
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                    Upon euthanasia
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                    Upon euthanasia
#
#                                  Term Source REF.7_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  NaN
#
#                                  Term Accession Number.7_x   Protocol REF.1_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                        NaN  sample collection
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                        NaN  sample collection
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                        NaN  sample collection
#
#                                 Parameter Value[Euthanasia Method,http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C90336,NCIT]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3          Isoflurane, Thoracotomy, Cardiac Puncture
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4          Isoflurane, Thoracotomy, Cardiac Puncture
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5          Isoflurane, Thoracotomy, Cardiac Puncture
#
#                                  Term Source REF.8_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  NaN
#
#                                  Term Accession Number.8_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                        NaN
#
#                                  Parameter Value[Carcass Preservation Method]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                                           NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                                           NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                                           NaN
#
#                                 Unit.2_x Term Source REF.9_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3      NaN                 NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4      NaN                 NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5      NaN                 NaN
#
#                                 Term Accession Number.9_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                       NaN
#
#                                  Parameter Value[Carcass Weight] Unit.3_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                            30.31     gram
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                            27.76     gram
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                            28.04     gram
#
#                                 Term Source REF.10_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                   UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                   UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                   UO
#
#                                                 Term Accession Number.10_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://purl.obolibrary.org/obo/UO_0000021
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://purl.obolibrary.org/obo/UO_0000021
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://purl.obolibrary.org/obo/UO_0000021
#
#                                 Comment[LSDA Sample Name] Material Type  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3         Spleen LAR-Base 3        spleen
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4         Spleen LAR-Base 4        spleen
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5         Spleen LAR-Base 5        spleen
#
#                                 Term Source REF.11_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3               UBERON
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4               UBERON
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5               UBERON
#
#                                                     Term Accession Number.11_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://purl.obolibrary.org/obo/UBERON_0002106
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://purl.obolibrary.org/obo/UBERON_0002106
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://purl.obolibrary.org/obo/UBERON_0002106
#
#                                 Comment[Launch Date] Comment[Euthanasia Date]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3          09-Dec-2017              09-Dec-2017
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4          09-Dec-2017              09-Dec-2017
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5          09-Dec-2017              09-Dec-2017
#
#                                 Comment[Dissection Date]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3              09-Dec-2017
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4              09-Dec-2017
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5              09-Dec-2017
#
#                                 Parameter Value[Sample Preservation Method]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                             Liquid Nitrogen
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                             Liquid Nitrogen
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                             Liquid Nitrogen
#
#                                 Term Source REF.12_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                 NCIT
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                 NCIT
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                 NCIT
#
#                                                         Term Accession Number.12_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
#
#                                  Parameter Value[Sample Storage Temperature]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                                          -80
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                                          -80
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                                          -80
#
#                                        Unit.4_x Term Source REF.13_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  degree Celsius                   UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  degree Celsius                   UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  degree Celsius                   UO
#
#                                                 Term Accession Number.13_x  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://purl.obolibrary.org/obo/UO_0000027
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://purl.obolibrary.org/obo/UO_0000027
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://purl.obolibrary.org/obo/UO_0000027
#
#                                           Protocol REF_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  nucleic acid extraction
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  nucleic acid extraction
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  nucleic acid extraction
#
#                                 Parameter Value[QA Instrument]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3       Agilent 2100 Bioanalyzer
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4       Agilent 2100 Bioanalyzer
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5       Agilent 2100 Bioanalyzer
#
#                                 Parameter Value[QA Assay]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3       RNA 6000 Nano Assay
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4       RNA 6000 Nano Assay
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5       RNA 6000 Nano Assay
#
#                                  Parameter Value[QA Score]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                        5.9
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                        6.6
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                        8.7
#
#                                                Unit_y Term Source REF_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  RNA Integrity Number              NCIT
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  RNA Integrity Number              NCIT
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  RNA Integrity Number              NCIT
#
#                                                            Term Accession Number_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
#
#                                                     Extract Name  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5
#
#                                   Protocol REF.1_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  spike-in protocol
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  spike-in protocol
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  spike-in protocol
#
#                                 Parameter Value[Spike-in Quality Control]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3              ERCC ExFold RNA Spike-In Mix
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4              ERCC ExFold RNA Spike-In Mix
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5              ERCC ExFold RNA Spike-In Mix
#
#                                  Term Source REF.1_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  NaN
#
#                                  Term Accession Number.1_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                        NaN
#
#                                 Parameter Value[Spike-in Mix number]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                                Mix 1
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                                Mix 1
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                                Mix 1
#
#                                  Term Source REF.2_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  NaN
#
#                                  Term Accession Number.2_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                        NaN
#
#                                        Protocol REF.2  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  library construction
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  library construction
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  library construction
#
#                                 Parameter Value[library selection]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                     Ribo-depletion
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                     Ribo-depletion
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                     Ribo-depletion
#
#                                 Parameter Value[library layout]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                          PAIRED
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                          PAIRED
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                          PAIRED
#
#                                 Parameter Value[stranded]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  STRANDED
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  STRANDED
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  STRANDED
#
#                                 Parameter Value[Library QA Instrument]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3               Agilent 4200 TapeStation
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4               Agilent 4200 TapeStation
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5               Agilent 4200 TapeStation
#
#                                  Term Source REF.3_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  NaN
#
#                                  Term Accession Number.3_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                        NaN
#
#                                 Parameter Value[Library QA Assay]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  D1000 ScreenTape
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  D1000 ScreenTape
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  D1000 ScreenTape
#
#                                  Term Source REF.4_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  NaN
#
#                                  Term Accession Number.4_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                        NaN
#
#                                  Parameter Value[Fragment Size]   Unit.1_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                             287  base pair
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                             289  base pair
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                             283  base pair
#
#                                 Term Source REF.5_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  UO
#
#                                                  Term Accession Number.5_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://purl.obolibrary.org/obo/UO_0000244
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://purl.obolibrary.org/obo/UO_0000244
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://purl.obolibrary.org/obo/UO_0000244
#
#                                           Protocol REF.3  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  nucleic acid sequencing
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  nucleic acid sequencing
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  nucleic acid sequencing
#
#                                 Parameter Value[sequencing instrument]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  Illumina NovaSeq 6000
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  Illumina NovaSeq 6000
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  Illumina NovaSeq 6000
#
#                                 Parameter Value[base caller]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                    bcl2fastq
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                    bcl2fastq
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                    bcl2fastq
#
#                                  Parameter Value[Read Length,http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C153362,NCIT]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                                                149
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                                                149
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                                                149
#
#                                   Unit.2_y Term Source REF.6_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  base pair                  UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  base pair                  UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  base pair                  UO
#
#                                                  Term Accession Number.6_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://purl.obolibrary.org/obo/UO_0000244
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://purl.obolibrary.org/obo/UO_0000244
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://purl.obolibrary.org/obo/UO_0000244
#
#                                 Assay Name  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3    rna-seq
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4    rna-seq
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5    rna-seq
#
#                                  Parameter Value[rRNA Contamination] Unit.3_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                                 0.85  percent
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                                 0.35  percent
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                                 1.04  percent
#
#                                 Term Source REF.7_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  UO
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  UO
#
#                                                  Term Accession Number.7_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://purl.obolibrary.org/obo/UO_0000187
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://purl.obolibrary.org/obo/UO_0000187
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://purl.obolibrary.org/obo/UO_0000187
#
#                                  Parameter Value[Read Depth,http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C155320,NCIT]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                                          106545145
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                                          111068823
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                                          110761283
#
#                                 Unit.4_y Term Source REF.8_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3     read                  SO
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4     read                  SO
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5     read                  SO
#
#                                                  Term Accession Number.8_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  http://purl.obolibrary.org/obo/SO_0000150
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  http://purl.obolibrary.org/obo/SO_0000150
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  http://purl.obolibrary.org/obo/SO_0000150
#
#                                                                      Raw Data File  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GLDS-246_rna-seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GLDS-246_rna-seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GLDS-246_rna-seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...
#
#                                                 Parameter Value[Fastqc File Names]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GLDS-246_rna-seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GLDS-246_rna-seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GLDS-246_rna-seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...
#
#                                  Term Source REF.9_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                  NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                  NaN
#
#                                  Term Accession Number.9_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                        NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                        NaN
#
#                                                Parameter Value[Multiqc File Names]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GLDS-246_rna-seq_raw_multiqc_report.html, GLDS...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GLDS-246_rna-seq_raw_multiqc_report.html, GLDS...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GLDS-246_rna-seq_raw_multiqc_report.html, GLDS...
#
#                                  Term Source REF.10_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                   NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                   NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                   NaN
#
#                                  Term Accession Number.10_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                         NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                         NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                         NaN
#
#                                                           Protocol REF.4  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GeneLab RNAseq data processing protocol
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GeneLab RNAseq data processing protocol
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GeneLab RNAseq data processing protocol
#
#                                 Parameter Value[trimmed sequence data,http://purl.obolibrary.org/obo/OBI_0002569,OBI]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...
#
#                                  Term Source REF.11_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                   NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                   NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                   NaN
#
#                                  Term Accession Number.11_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                         NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                         NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                         NaN
#
#                                 Parameter Value[Trimmed Sequence Data Fastqc File]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...
#
#                                  Term Source REF.12_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                   NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                   NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                   NaN
#
#                                  Term Accession Number.12_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                         NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                         NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                         NaN
#
#                                 Parameter Value[Trimmed Sequence Data Multiqc File]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GLDS-246_rna_seq_trimmed_multiqc_report.html, ...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GLDS-246_rna_seq_trimmed_multiqc_report.html, ...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GLDS-246_rna_seq_trimmed_multiqc_report.html, ...
#
#                                  Term Source REF.13_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                   NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                   NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                   NaN
#
#                                  Term Accession Number.13_y  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                         NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                         NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                         NaN
#
#                                                    Parameter Value[Trimmed Report]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...
#
#                                  Term Source REF.14  Term Accession Number.14  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                 NaN                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                 NaN                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                 NaN                       NaN
#
#                                 Parameter Value[aligned sequence data,http://purl.obolibrary.org/obo/OBI_0002580,OBI]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...
#
#                                  Term Source REF.15  Term Accession Number.15  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                 NaN                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                 NaN                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                 NaN                       NaN
#
#                                                    Parameter Value[Alignment Logs]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...
#
#                                  Term Source REF.16  Term Accession Number.16  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                 NaN                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                 NaN                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                 NaN                       NaN
#
#                                              Parameter Value[Raw Counts Data File]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep1_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep2_...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GLDS-246_rna_seq_Mmus_C57-6T_SPL_BSL_LAR_Rep3_...
#
#                                  Term Source REF.17  Term Accession Number.17  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                 NaN                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                 NaN                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                 NaN                       NaN
#
#                                       Parameter Value[Normalized Counts Data File]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GLDS-246_rna_seq_Normalized_Counts.csv, GLDS-2...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GLDS-246_rna_seq_Normalized_Counts.csv, GLDS-2...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GLDS-246_rna_seq_Normalized_Counts.csv, GLDS-2...
#
#                                  Term Source REF.18  Term Accession Number.18  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                 NaN                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                 NaN                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                 NaN                       NaN
#
#                                 Parameter Value[differential expression analysis data transformation,http://purl.obolibrary.org/obo/OBI_0000650,OBI]  \
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3  GLDS-246_rna_seq_contrasts.csv, GLDS-246_rna_s...
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4  GLDS-246_rna_seq_contrasts.csv, GLDS-246_rna_s...
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5  GLDS-246_rna_seq_contrasts.csv, GLDS-246_rna_s...
#
#                                  Term Source REF.19  Term Accession Number.19
# Sample Name
# Mmus_C57-6T_SPL_BSL_LAR_Rep1_B3                 NaN                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep2_B4                 NaN                       NaN
# Mmus_C57-6T_SPL_BSL_LAR_Rep3_B5                 NaN                       NaN

# %% [markdown]
# Other GLDS studies (ie. Ground) have other factor than Spaceflight.  It's important to inspect the factors in your analysis.

# %%
# Select Spaceflight and Euthanasia  
flightground = combined['Factor Value[Spaceflight]'].isin(['Space Flight', 'Ground Control'])
lar = combined['Factor Value[Euthanasia]'] == 'On Earth'

# %%
# Sometimes number in [Spike-in Mix number] is spelled 'Number' and this could cause error in mismatch search 
fewsamples = combined[flightground].loc[:,['Factor Value[Spaceflight]','Parameter Value[Spike-in Mix number]']]
fewsamples.index = fewsamples.index.str.replace('-','_')

# %%
fewsamples.columns = ['Spaceflight','Mix']
fewsamples.to_csv('ERCC/fewsamples.csv')

# %%
ercc_counts.columns = ercc_counts.columns.str.replace('-','_')
fewcounts = ercc_counts.loc[:,fewsamples.index]

# %%
fewcounts.to_csv('ERCC/fewcounts.csv')
# Remove any sample that has all 0 counts in fewcounts.csv. Remove same sample name in fewsamples.csv also.

# %% [markdown]
# ## Perform DESeq2 analysis of ERCC counts
#
# Switch to R script to perform DE on ERCC unnormalized counts. Contrast (pair-wise) Mix 1 and Mix 2 comparison returns mean normalized counts, log2FC (fold change), p-value, adj. p-value.

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# if (!requireNamespace("BiocManager", quietly = TRUE))
#     install.packages("BiocManager")
#
# BiocManager::install("DESeq2")
# Out:
# R[write to console]: 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.rstudio.com
#
#
# R[write to console]: Bioconductor version 3.12 (BiocManager 1.30.15), R 4.0.5 (2021-03-31)
#
# R[write to console]: Old packages: 'IRkernel', 'devtools', 'dplyr', 'openssl', 'rmarkdown',
#   'stringi', 'systemfonts'
# Update all/some/none? [a/s/n]: n

# %%
# %%R
# library("DESeq2")
# Out:
# R[write to console]: Loading required package: S4Vectors
#
# R[write to console]: Loading required package: stats4
#
# R[write to console]: Loading required package: BiocGenerics
#
# R[write to console]: Loading required package: parallel
#
# R[write to console]:
# Attaching package: ‘BiocGenerics’
#
#
# R[write to console]: The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# R[write to console]:
# Attaching package: ‘S4Vectors’
#
#
# R[write to console]: The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# R[write to console]: Loading required package: IRanges
#
# R[write to console]: Loading required package: GenomicRanges
#
# R[write to console]: Loading required package: GenomeInfoDb
#
# R[write to console]: Loading required package: SummarizedExperiment
#
# R[write to console]: Loading required package: MatrixGenerics
#
# R[write to console]: Loading required package: matrixStats
#
# R[write to console]:
# Attaching package: ‘MatrixGenerics’
#
#
# R[write to console]: The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# R[write to console]: Loading required package: Biobase
#
# R[write to console]: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# R[write to console]:
# Attaching package: ‘Biobase’
#
#
# R[write to console]: The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# R[write to console]: The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians

# %%
# %%R
# cts <- as.matrix(read.csv('ERCC/fewcounts.csv',sep=",",row.names="Gene_ID"))
# coldata <- read.csv('ERCC/fewsamples.csv', row.names=1)

# %%
# %%R
# coldata$Spaceflight <- factor(coldata$Spaceflight)
# coldata$Mix <- factor(coldata$Mix)

# %%
# %%R
# all(rownames(coldata) == colnames(cts))
# Out:
# [1] TRUE

# %%
# %%R
# dds <- DESeqDataSetFromMatrix(countData = cts,
#                               colData = coldata,
#                               design = ~ Mix)
# dds
# Out:
# R[write to console]: converting counts to integer mode
#
# R[write to console]:   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
# class: DESeqDataSet
# dim: 92 31
# metadata(1): version
# assays(1): counts
# rownames(92): ERCC-00130 ERCC-00096 ... ERCC-00156 ERCC-00168
# rowData names(0):
# colnames(31): Mmus_C57_6T_SPL_GC_LAR_Rep1_G3
#   Mmus_C57_6T_SPL_GC_LAR_Rep2_G4 ... Mmus_C57_6T_SPL_FLT_ISS_T_Rep6_F9
#   Mmus_C57_6T_SPL_FLT_ISS_T_Rep7_F10
# colData names(2): Spaceflight Mix

# %% [markdown]
# Not included here are standard deviation and average to Mix 1 and Mix 2 that are reported in conventional DESeq2.

# %%
# %%R
# dds <- DESeq(dds)
# res <- results(dds, contrast=c("Mix","Mix 1","Mix 2"))
# res
# Out:
# R[write to console]: estimating size factors
#
# R[write to console]:   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]:   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# R[write to console]: final dispersion estimates
#
# R[write to console]:   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# R[write to console]: fitting model and testing
#
# R[write to console]:   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
# log2 fold change (MLE): Mix Mix 1 vs Mix 2
# Wald test p-value: Mix Mix 1 vs Mix 2
# DataFrame with 92 rows and 6 columns
#             baseMean log2FoldChange     lfcSE      stat       pvalue
#            <numeric>      <numeric> <numeric> <numeric>    <numeric>
# ERCC-00130  1678.123       2.256584 0.0783835  28.78901 2.94436e-182
# ERCC-00096   818.423       0.170055 0.0557989   3.04764  2.30644e-03
# ERCC-00002   983.673      -0.817071 0.0710113 -11.50621  1.22751e-30
# ERCC-00074   717.105      -0.335554 0.0845378  -3.96928  7.20905e-05
# ERCC-00004   141.161       2.370160 0.1183471  20.02718  3.19205e-89
# ...              ...            ...       ...       ...          ...
# ERCC-00117         0             NA        NA        NA           NA
# ERCC-00123         0             NA        NA        NA           NA
# ERCC-00142         0             NA        NA        NA           NA
# ERCC-00156         0             NA        NA        NA           NA
# ERCC-00168         0             NA        NA        NA           NA
#                    padj
#               <numeric>
# ERCC-00130 2.06105e-180
# ERCC-00096  8.07255e-03
# ERCC-00002  1.43209e-29
# ERCC-00074  3.60453e-04
# ERCC-00004  7.44813e-88
# ...                 ...
# ERCC-00117           NA
# ERCC-00123           NA
# ERCC-00142           NA
# ERCC-00156           NA
# ERCC-00168           NA

# %%
# %%R
# write.csv(res, 'ERCC/ERCC_DESeq2.csv')

# %%
# %%R
# normcounts = counts(dds, normalized=TRUE)
# write.csv(normcounts, 'ERCC/ERCC_normcounts.csv')

# %% [markdown]
# ## Analyze DESeq2 results

# %%
import pandas as pd
from urllib.request import urlopen, quote, urlretrieve
import seaborn as sns
import matplotlib.pyplot as plt

# %%
deseq2out = pd.read_csv('ERCC/ERCC_DESeq2.csv', index_col=0)
#deseq2out.index = deseq2out.index.str.replace('_','-')
deseq2out.rename(columns ={'baseMean' : 'meanNormCounts'}, inplace = True)
deseq2out.head()
# Out:
#             meanNormCounts  log2FoldChange     lfcSE       stat  \
# ERCC-00130     1678.123362        2.256584  0.078384  28.789012
# ERCC-00096      818.422536        0.170055  0.055799   3.047642
# ERCC-00002      983.673419       -0.817071  0.071011 -11.506213
# ERCC-00074      717.105010       -0.335554  0.084538  -3.969279
# ERCC-00004      141.161223        2.370160  0.118347  20.027184
#
#                    pvalue           padj
# ERCC-00130  2.944364e-182  2.061055e-180
# ERCC-00096   2.306443e-03   8.072549e-03
# ERCC-00002   1.227508e-30   1.432092e-29
# ERCC-00074   7.209055e-05   3.604527e-04
# ERCC-00004   3.192055e-89   7.448128e-88

# %%
# Get ERCC files
ercc_url = 'https://assets.thermofisher.com/TFS-Assets/LSG/manuals/cms_095046.txt'
filehandle, _ = urlretrieve(ercc_url)
ercc_table = pd.read_csv(filehandle, '\t', index_col='ERCC ID')
ercc_table.head(n=3)
# Out:
#             Re-sort ID subgroup  concentration in Mix 1 (attomoles/ul)  \
# ERCC ID
# ERCC-00130           1        A                                30000.0
# ERCC-00004           2        A                                 7500.0
# ERCC-00136           3        A                                 1875.0
#
#             concentration in Mix 2 (attomoles/ul)  expected fold-change ratio  \
# ERCC ID
# ERCC-00130                                7500.00                         4.0
# ERCC-00004                                1875.00                         4.0
# ERCC-00136                                 468.75                         4.0
#
#             log2(Mix 1/Mix 2)
# ERCC ID
# ERCC-00130                2.0
# ERCC-00004                2.0
# ERCC-00136                2.0

# %%
combined = deseq2out.merge(ercc_table, left_index=True, right_index=True)
combined.head()
# Out:
#             meanNormCounts  log2FoldChange     lfcSE       stat  \
# ERCC-00130     1678.123362        2.256584  0.078384  28.789012
# ERCC-00096      818.422536        0.170055  0.055799   3.047642
# ERCC-00002      983.673419       -0.817071  0.071011 -11.506213
# ERCC-00074      717.105010       -0.335554  0.084538  -3.969279
# ERCC-00004      141.161223        2.370160  0.118347  20.027184
#
#                    pvalue           padj  Re-sort ID subgroup  \
# ERCC-00130  2.944364e-182  2.061055e-180           1        A
# ERCC-00096   2.306443e-03   8.072549e-03          24        B
# ERCC-00002   1.227508e-30   1.432092e-29          70        D
# ERCC-00074   7.209055e-05   3.604527e-04          47        C
# ERCC-00004   3.192055e-89   7.448128e-88           2        A
#
#             concentration in Mix 1 (attomoles/ul)  \
# ERCC-00130                                30000.0
# ERCC-00096                                15000.0
# ERCC-00002                                15000.0
# ERCC-00074                                15000.0
# ERCC-00004                                 7500.0
#
#             concentration in Mix 2 (attomoles/ul)  expected fold-change ratio  \
# ERCC-00130                                 7500.0                        4.00
# ERCC-00096                                15000.0                        1.00
# ERCC-00002                                30000.0                        0.50
# ERCC-00074                                22500.0                        0.67
# ERCC-00004                                 1875.0                        4.00
#
#             log2(Mix 1/Mix 2)
# ERCC-00130               2.00
# ERCC-00096               0.00
# ERCC-00002              -1.00
# ERCC-00074              -0.58
# ERCC-00004               2.00

# %%
combined['cleaned_padj'] = combined['padj']
combined.loc[(combined.cleaned_padj < 0.00001),'cleaned_padj']=0.00001

combined['cleaned_pvalue'] = combined['pvalue']
combined.loc[(combined.cleaned_pvalue < 0.00001),'cleaned_pvalue']=0.00001

combined.head()
# Out:
#             meanNormCounts  log2FoldChange     lfcSE       stat  \
# ERCC-00130     1678.123362        2.256584  0.078384  28.789012
# ERCC-00096      818.422536        0.170055  0.055799   3.047642
# ERCC-00002      983.673419       -0.817071  0.071011 -11.506213
# ERCC-00074      717.105010       -0.335554  0.084538  -3.969279
# ERCC-00004      141.161223        2.370160  0.118347  20.027184
#
#                    pvalue           padj  Re-sort ID subgroup  \
# ERCC-00130  2.944364e-182  2.061055e-180           1        A
# ERCC-00096   2.306443e-03   8.072549e-03          24        B
# ERCC-00002   1.227508e-30   1.432092e-29          70        D
# ERCC-00074   7.209055e-05   3.604527e-04          47        C
# ERCC-00004   3.192055e-89   7.448128e-88           2        A
#
#             concentration in Mix 1 (attomoles/ul)  \
# ERCC-00130                                30000.0
# ERCC-00096                                15000.0
# ERCC-00002                                15000.0
# ERCC-00074                                15000.0
# ERCC-00004                                 7500.0
#
#             concentration in Mix 2 (attomoles/ul)  expected fold-change ratio  \
# ERCC-00130                                 7500.0                        4.00
# ERCC-00096                                15000.0                        1.00
# ERCC-00002                                30000.0                        0.50
# ERCC-00074                                22500.0                        0.67
# ERCC-00004                                 1875.0                        4.00
#
#             log2(Mix 1/Mix 2)  cleaned_padj  cleaned_pvalue
# ERCC-00130               2.00      0.000010        0.000010
# ERCC-00096               0.00      0.008073        0.002306
# ERCC-00002              -1.00      0.000010        0.000010
# ERCC-00074              -0.58      0.000360        0.000072
# ERCC-00004               2.00      0.000010        0.000010

# %%
# Remember to change file name to GLDS# analyzing
combined.filter(items = ['ERCC ID', 'meanNormCounts', 'cleaned_pvalue','cleaned_padj']).to_csv('ERCC/ERCC_lodr_GLDS-246_mqc.csv')

# %%
fig, ax = plt.subplots(figsize=(10, 7))

sns.scatterplot(data=combined, x="meanNormCounts", y="cleaned_pvalue",
            hue="expected fold-change ratio",
                palette=['red','green','black','blue'], ax=ax)

sns.lineplot(data=combined, x="meanNormCounts", y="cleaned_pvalue",
            hue="expected fold-change ratio",
                palette=['red','green','black','blue'], ax=ax)

#g.set_xscale("log", base=2)
ax.set_xscale("linear");
ax.set_yscale("log");

# %%
fig, ax = plt.subplots(figsize=(10, 7))

sns.scatterplot(data=combined, x="meanNormCounts", y="cleaned_padj",
            hue="expected fold-change ratio",
                palette=['red','green','black','blue'], ax=ax)

sns.lineplot(data=combined, x="meanNormCounts", y="cleaned_padj",
            hue="expected fold-change ratio",
                palette=['red','green','black','blue'], ax=ax)

#g.set_xscale("log", base=2)
ax.set_xscale("linear");
ax.set_yscale("log");

# %% [markdown]
# Run MultiQC report on select *mqc files separately in command line.
